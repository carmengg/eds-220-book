# %%
import pandas as pd
import matplotlib.pyplot as plt

import geopandas as gpd
import contextily as ctx

# %%
pd.set_option("display.max.columns", None)

# %%
# read in Arctic communities data
communities = gpd.read_file('https://cn.dataone.org/cn/v2/resolve/urn%3Auuid%3Aed7718ae-fb0d-43dd-9270-fbfe80bfc7a4')
communities.head()
# Out:
#           name  population country  geoname-id                   geometry
# 0      Udomlya       32373      RU      452949  POINT (34.99250 57.87944)
# 1     Valmiera       26963      LV      453754  POINT (25.42751 57.54108)
# 2    Ventspils       42644      LV      454310  POINT (21.57288 57.38988)
# 3  Vec-Liepāja       85260      LV      454432  POINT (21.01667 56.53333)
# 4       Tukums       18348      LV      454768  POINT (23.15528 56.96694)

# %%
# calculate number of communities by country
n_comms = communities.groupby('country').count().name.rename('n_communities')
n_comms = pd.DataFrame(n_comms).reset_index()
n_comms
# Out:
#    country  n_communities
# 0       AX              1
# 1       BY              8
# 2       CA              7
# 3       DK             72
# 4       EE             14
# 5       FI             98
# 6       FO              1
# 7       GB             96
# 8       GL              1
# 9       IS              5
# 10      LT             26
# 11      LV             25
# 12      NO             48
# 13      RU            774
# 14      SE            133
# 15      US            115

# %%
# make histogram

# %%
# select Scandinavia
scandi_codes = ['DK','NO','SE','FO','FI','IS','AX']
scandi_n_comms = n_comms[n_comms.country.isin(scandi_codes)].copy()
scandi_n_comms
# Out:
#    country  n_communities
# 0       AX              1
# 3       DK             72
# 5       FI             98
# 6       FO              1
# 9       IS              5
# 12      NO             48
# 14      SE            133

# %%
scandi_names = ['Aland Islands',
                'Denmark',
                'Finland',
                'Faroe Islands',
                'Iceland',
                'Norway',
                'Sweden']
scandi_n_comms['admin'] = scandi_names
scandi_n_comms
# Out:
#    country  n_communities          admin
# 0       AX              1  Aland Islands
# 3       DK             72        Denmark
# 5       FI             98        Finland
# 6       FO              1  Faroe Islands
# 9       IS              5        Iceland
# 12      NO             48         Norway
# 14      SE            133         Sweden

# %%
# import countries polygons
countries = gpd.read_file('ne_50m_admin_0_countries/ne_50m_admin_0_countries.shp')
countries
# Out:
#           featurecla  scalerank  LABELRANK   SOVEREIGNT SOV_A3  ADM0_DIF  \
# 0    Admin-0 country          1          3     Zimbabwe    ZWE         0
# 1    Admin-0 country          1          3       Zambia    ZMB         0
# 2    Admin-0 country          1          3        Yemen    YEM         0
# 3    Admin-0 country          3          2      Vietnam    VNM         0
# 4    Admin-0 country          5          3    Venezuela    VEN         0
# ..               ...        ...        ...          ...    ...       ...
# 237  Admin-0 country          1          3  Afghanistan    AFG         0
# 238  Admin-0 country          1          5      Kashmir    KAS         0
# 239  Admin-0 country          3          4   Antarctica    ATA         0
# 240  Admin-0 country          3          6  Netherlands    NL1         1
# 241  Admin-0 country          5          6       Tuvalu    TUV         0
#
#      LEVEL               TYPE   TLC            ADMIN ADM0_A3  GEOU_DIF  \
# 0        2  Sovereign country     1         Zimbabwe     ZWE         0
# 1        2  Sovereign country     1           Zambia     ZMB         0
# 2        2  Sovereign country     1            Yemen     YEM         0
# 3        2  Sovereign country     1          Vietnam     VNM         0
# 4        2  Sovereign country     1        Venezuela     VEN         0
# ..     ...                ...   ...              ...     ...       ...
# 237      2  Sovereign country     1      Afghanistan     AFG         0
# 238      2      Indeterminate  None  Siachen Glacier     KAS         0
# 239      2      Indeterminate     1       Antarctica     ATA         0
# 240      2            Country     1     Sint Maarten     SXM         0
# 241      2  Sovereign country     1           Tuvalu     TUV         0
#
#              GEOUNIT GU_A3  SU_DIF          SUBUNIT SU_A3  BRK_DIFF  \
# 0           Zimbabwe   ZWE       0         Zimbabwe   ZWE         0
# 1             Zambia   ZMB       0           Zambia   ZMB         0
# 2              Yemen   YEM       0            Yemen   YEM         0
# 3            Vietnam   VNM       0          Vietnam   VNM         0
# 4          Venezuela   VEN       0        Venezuela   VEN         0
# ..               ...   ...     ...              ...   ...       ...
# 237      Afghanistan   AFG       0      Afghanistan   AFG         0
# 238  Siachen Glacier   KAS       0  Siachen Glacier   KAS         1
# 239       Antarctica   ATA       0       Antarctica   ATA         0
# 240     Sint Maarten   SXM       0     Sint Maarten   SXM         0
# 241           Tuvalu   TUV       0           Tuvalu   TUV         0
#
#                 NAME        NAME_LONG BRK_A3         BRK_NAME  \
# 0           Zimbabwe         Zimbabwe    ZWE         Zimbabwe
# 1             Zambia           Zambia    ZMB           Zambia
# 2              Yemen            Yemen    YEM            Yemen
# 3            Vietnam          Vietnam    VNM          Vietnam
# 4          Venezuela        Venezuela    VEN        Venezuela
# ..               ...              ...    ...              ...
# 237      Afghanistan      Afghanistan    AFG      Afghanistan
# 238  Siachen Glacier  Siachen Glacier    B45  Siachen Glacier
# 239       Antarctica       Antarctica    ATA       Antarctica
# 240     Sint Maarten     Sint Maarten    SXM     Sint Maarten
# 241           Tuvalu           Tuvalu    TUV           Tuvalu
#
#              BRK_GROUP   ABBREV POSTAL                         FORMAL_EN  \
# 0                 None    Zimb.     ZW              Republic of Zimbabwe
# 1                 None   Zambia     ZM                Republic of Zambia
# 2                 None     Yem.     YE                 Republic of Yemen
# 3                 None    Viet.     VN     Socialist Republic of Vietnam
# 4                 None     Ven.     VE  Bolivarian Republic of Venezuela
# ..                 ...      ...    ...                               ...
# 237               None     Afg.     AF      Islamic State of Afghanistan
# 238  Jammu and Kashmir  Siachen     SG                              None
# 239               None     Ant.     AQ                              None
# 240               None   St. M.     SX         Sint Maarten (Dutch part)
# 241               None     Tuv.     TV                            Tuvalu
#
#                               FORMAL_FR    NAME_CIAWF  NOTE_ADM0  \
# 0                                  None      Zimbabwe       None
# 1                                  None        Zambia       None
# 2                                  None         Yemen       None
# 3                                  None       Vietnam       None
# 4    República Bolivariana de Venezuela     Venezuela       None
# ..                                  ...           ...        ...
# 237                                None   Afghanistan       None
# 238                                None          None       None
# 239                                None          None  By treaty
# 240                                None  Sint Maarten      Neth.
# 241                                None        Tuvalu       None
#
#                                        NOTE_BRK                 NAME_SORT  \
# 0                                          None                  Zimbabwe
# 1                                          None                    Zambia
# 2                                          None               Yemen, Rep.
# 3                                          None                   Vietnam
# 4                                          None             Venezuela, RB
# ..                                          ...                       ...
# 237                                        None               Afghanistan
# 238               Claimed by Pakistan and India                   Kashmir
# 239  Multiple claims held in abeyance by treaty                Antarctica
# 240                                        None  St. Maarten (Dutch part)
# 241                                        None                    Tuvalu
#
#     NAME_ALT  MAPCOLOR7  MAPCOLOR8  MAPCOLOR9  MAPCOLOR13     POP_EST  \
# 0       None          1          5          3           9  14645468.0
# 1       None          5          8          5          13  17861030.0
# 2       None          5          3          3          11  29161922.0
# 3       None          5          6          5           4  96462106.0
# 4       None          1          3          1           4  28515829.0
# ..       ...        ...        ...        ...         ...         ...
# 237     None          5          6          8           7  38041754.0
# 238     None          3          7          6         -99      6000.0
# 239     None          4          5          1         -99      4490.0
# 240     None          4          2          2           9     40733.0
# 241     None          1          3          8           5     11646.0
#
#      POP_RANK  POP_YEAR  GDP_MD  GDP_YEAR                    ECONOMY  \
# 0          14      2019   21440      2019    5. Emerging region: G20
# 1          14      2019   23309      2019  7. Least developed region
# 2          15      2019   22581      2019  7. Least developed region
# 3          16      2019  261921      2019    5. Emerging region: G20
# 4          15      2019  482359      2014    5. Emerging region: G20
# ..        ...       ...     ...       ...                        ...
# 237        15      2019   19291      2019  7. Least developed region
# 238         5      2013      15      2013       6. Developing region
# 239         4      2019     898      2013       6. Developing region
# 240         7      2019    1185      2018       6. Developing region
# 241         6      2019      47      2019  7. Least developed region
#
#                   INCOME_GRP FIPS_10 ISO_A2 ISO_A2_EH ISO_A3 ISO_A3_EH ISO_N3  \
# 0              5. Low income      ZI     ZW        ZW    ZWE       ZWE    716
# 1     4. Lower middle income      ZA     ZM        ZM    ZMB       ZMB    894
# 2     4. Lower middle income      YM     YE        YE    YEM       YEM    887
# 3     4. Lower middle income      VM     VN        VN    VNM       VNM    704
# 4     3. Upper middle income      VE     VE        VE    VEN       VEN    862
# ..                       ...     ...    ...       ...    ...       ...    ...
# 237            5. Low income      AF     AF        AF    AFG       AFG    004
# 238   4. Lower middle income     -99    -99       -99    -99       -99    -99
# 239  2. High income: nonOECD      AY     AQ        AQ    ATA       ATA    010
# 240  2. High income: nonOECD      NT     SX        SX    SXM       SXM    534
# 241   3. Upper middle income      TV     TV        TV    TUV       TUV    798
#
#     ISO_N3_EH UN_A3 WB_A2 WB_A3    WOE_ID  WOE_ID_EH  \
# 0         716   716    ZW   ZWE  23425004   23425004
# 1         894   894    ZM   ZMB  23425003   23425003
# 2         887   887    RY   YEM  23425002   23425002
# 3         704   704    VN   VNM  23424984   23424984
# 4         862   862    VE   VEN  23424982   23424982
# ..        ...   ...   ...   ...       ...        ...
# 237       004   004    AF   AFG  23424739   23424739
# 238       -99  -099   -99   -99  23424928   23424928
# 239       010   010   -99   -99  28289409   28289409
# 240       534   534    SX   SXM       -90   23425000
# 241       798   798    TV   TUV  23424970   23424970
#
#                                               WOE_NOTE ADM0_ISO ADM0_DIFF  \
# 0                           Exact WOE match as country      ZWE      None
# 1                           Exact WOE match as country      ZMB      None
# 2                           Exact WOE match as country      YEM      None
# 3                           Exact WOE match as country      VNM      None
# 4                           Exact WOE match as country      VEN      None
# ..                                                 ...      ...       ...
# 237                         Exact WOE match as country      AFG      None
# 238                         Exact WOE match as country      -99      None
# 239                         Exact WOE match as country      ATA      None
# 240  Expired subunits of Netherlands Antilles (2342...      SXM      None
# 241                         Exact WOE match as country      TUV      None
#
#     ADM0_TLC ADM0_A3_US ADM0_A3_FR ADM0_A3_RU ADM0_A3_ES ADM0_A3_CN  \
# 0        ZWE        ZWE        ZWE        ZWE        ZWE        ZWE
# 1        ZMB        ZMB        ZMB        ZMB        ZMB        ZMB
# 2        YEM        YEM        YEM        YEM        YEM        YEM
# 3        VNM        VNM        VNM        VNM        VNM        VNM
# 4        VEN        VEN        VEN        VEN        VEN        VEN
# ..       ...        ...        ...        ...        ...        ...
# 237      AFG        AFG        AFG        AFG        AFG        AFG
# 238      -99        B45        IND        IND        IND        IND
# 239      ATA        ATA        ATA        ATA        ATA        ATA
# 240      SXM        SXM        SXM        SXM        SXM        SXM
# 241      TUV        TUV        TUV        TUV        TUV        TUV
#
#     ADM0_A3_TW ADM0_A3_IN ADM0_A3_NP ADM0_A3_PK ADM0_A3_DE ADM0_A3_GB  \
# 0          ZWE        ZWE        ZWE        ZWE        ZWE        ZWE
# 1          ZMB        ZMB        ZMB        ZMB        ZMB        ZMB
# 2          YEM        YEM        YEM        YEM        YEM        YEM
# 3          VNM        VNM        VNM        VNM        VNM        VNM
# 4          VEN        VEN        VEN        VEN        VEN        VEN
# ..         ...        ...        ...        ...        ...        ...
# 237        AFG        AFG        AFG        AFG        AFG        AFG
# 238        IND        IND        IND        PAK        IND        IND
# 239        ATA        ATA        ATA        ATA        ATA        ATA
# 240        SXM        SXM        SXM        SXM        SXM        SXM
# 241        TUV        TUV        TUV        TUV        TUV        TUV
#
#     ADM0_A3_BR ADM0_A3_IL ADM0_A3_PS ADM0_A3_SA ADM0_A3_EG ADM0_A3_MA  \
# 0          ZWE        ZWE        ZWE        ZWE        ZWE        ZWE
# 1          ZMB        ZMB        ZMB        ZMB        ZMB        ZMB
# 2          YEM        YEM        YEM        YEM        YEM        YEM
# 3          VNM        VNM        VNM        VNM        VNM        VNM
# 4          VEN        VEN        VEN        VEN        VEN        VEN
# ..         ...        ...        ...        ...        ...        ...
# 237        AFG        AFG        AFG        AFG        AFG        AFG
# 238        IND        IND        IND        IND        IND        IND
# 239        ATA        ATA        ATA        ATA        ATA        ATA
# 240        SXM        SXM        SXM        SXM        SXM        SXM
# 241        TUV        TUV        TUV        TUV        TUV        TUV
#
#     ADM0_A3_PT ADM0_A3_AR ADM0_A3_JP ADM0_A3_KO ADM0_A3_VN ADM0_A3_TR  \
# 0          ZWE        ZWE        ZWE        ZWE        ZWE        ZWE
# 1          ZMB        ZMB        ZMB        ZMB        ZMB        ZMB
# 2          YEM        YEM        YEM        YEM        YEM        YEM
# 3          VNM        VNM        VNM        VNM        VNM        VNM
# 4          VEN        VEN        VEN        VEN        VEN        VEN
# ..         ...        ...        ...        ...        ...        ...
# 237        AFG        AFG        AFG        AFG        AFG        AFG
# 238        IND        IND        IND        IND        IND        PAK
# 239        ATA        ATA        ATA        ATA        ATA        ATA
# 240        SXM        SXM        SXM        SXM        SXM        SXM
# 241        TUV        TUV        TUV        TUV        TUV        TUV
#
#     ADM0_A3_ID ADM0_A3_PL ADM0_A3_GR ADM0_A3_IT ADM0_A3_NL ADM0_A3_SE  \
# 0          ZWE        ZWE        ZWE        ZWE        ZWE        ZWE
# 1          ZMB        ZMB        ZMB        ZMB        ZMB        ZMB
# 2          YEM        YEM        YEM        YEM        YEM        YEM
# 3          VNM        VNM        VNM        VNM        VNM        VNM
# 4          VEN        VEN        VEN        VEN        VEN        VEN
# ..         ...        ...        ...        ...        ...        ...
# 237        AFG        AFG        AFG        AFG        AFG        AFG
# 238        IND        IND        IND        IND        IND        IND
# 239        ATA        ATA        ATA        ATA        ATA        ATA
# 240        SXM        SXM        SXM        SXM        SXM        SXM
# 241        TUV        TUV        TUV        TUV        TUV        TUV
#
#     ADM0_A3_BD ADM0_A3_UA  ADM0_A3_UN  ADM0_A3_WB      CONTINENT   REGION_UN  \
# 0          ZWE        ZWE         -99         -99         Africa      Africa
# 1          ZMB        ZMB         -99         -99         Africa      Africa
# 2          YEM        YEM         -99         -99           Asia        Asia
# 3          VNM        VNM         -99         -99           Asia        Asia
# 4          VEN        VEN         -99         -99  South America    Americas
# ..         ...        ...         ...         ...            ...         ...
# 237        AFG        AFG         -99         -99           Asia        Asia
# 238        IND        IND         -99         -99           Asia        Asia
# 239        ATA        ATA         -99         -99     Antarctica  Antarctica
# 240        SXM        SXM         -99         -99  North America    Americas
# 241        TUV        TUV         -99         -99        Oceania     Oceania
#
#               SUBREGION                   REGION_WB  NAME_LEN  LONG_LEN  \
# 0        Eastern Africa          Sub-Saharan Africa         8         8
# 1        Eastern Africa          Sub-Saharan Africa         6         6
# 2          Western Asia  Middle East & North Africa         5         5
# 3    South-Eastern Asia         East Asia & Pacific         7         7
# 4         South America   Latin America & Caribbean         9         9
# ..                  ...                         ...       ...       ...
# 237       Southern Asia                  South Asia        11        11
# 238       Southern Asia                  South Asia        15        15
# 239          Antarctica                  Antarctica        10        10
# 240           Caribbean   Latin America & Caribbean        12        12
# 241           Polynesia         East Asia & Pacific         6         6
#
#      ABBREV_LEN  TINY  HOMEPART  MIN_ZOOM  MIN_LABEL  MAX_LABEL     LABEL_X  \
# 0             5   -99         1       0.0        2.5        8.0   29.925444
# 1             6   -99         1       0.0        3.0        8.0   26.395298
# 2             4   -99         1       0.0        3.0        8.0   45.874383
# 3             5     2         1       0.0        2.0        7.0  105.387292
# 4             4   -99         1       0.0        2.5        7.5  -64.599381
# ..          ...   ...       ...       ...        ...        ...         ...
# 237           4   -99         1       0.0        3.0        7.0   66.496586
# 238           7   -99         1       5.0        6.5        9.5   77.129553
# 239           4   -99         1       0.0        4.0        9.0   35.885455
# 240           6     4       -99       0.0        5.0       10.0  -63.070133
# 241           4     5         1       0.0        5.0       10.0  179.209587
#
#        LABEL_Y       NE_ID WIKIDATAID                  NAME_AR  \
# 0   -18.911640  1159321441       Q954                 زيمبابوي
# 1   -14.660804  1159321439       Q953                   زامبيا
# 2    15.328226  1159321425       Q805                    اليمن
# 3    21.715416  1159321417       Q881                   فيتنام
# 4     7.182476  1159321411       Q717                  فنزويلا
# ..         ...         ...        ...                      ...
# 237  34.164262  1159320319       Q889                أفغانستان
# 238  35.340606  1159320963    Q333946       نهر سياتشن الجليدي
# 239 -79.843222  1159320335        Q51  القارة القطبية الجنوبية
# 240  18.040880  1159321103     Q26273               سينت مارتن
# 241  -8.513717  1159321333       Q672                   توفالو
#
#              NAME_BN            NAME_DE          NAME_EN             NAME_ES  \
# 0        জিম্বাবুয়ে           Simbabwe         Zimbabwe            Zimbabue
# 1          জাম্বিয়া             Sambia           Zambia              Zambia
# 2            ইয়েমেন              Jemen            Yemen               Yemen
# 3          ভিয়েতনাম            Vietnam          Vietnam             Vietnam
# 4        ভেনেজুয়েলা          Venezuela        Venezuela           Venezuela
# ..               ...                ...              ...                 ...
# 237      আফগানিস্তান        Afghanistan      Afghanistan          Afganistán
# 238  সিয়াচেন হিমবাহ  Siachen-Gletscher  Siachen Glacier  Glaciar de Siachen
# 239  অ্যান্টার্কটিকা         Antarktika       Antarctica           Antártida
# 240    সিন্ট মার্টেন       Sint Maarten     Sint Maarten          San Martín
# 241           টুভালু             Tuvalu           Tuvalu              Tuvalu
#
#          NAME_FA             NAME_FR            NAME_EL       NAME_HE  \
# 0       زیمبابوه            Zimbabwe         Ζιμπάμπουε      זימבבואה
# 1         زامبیا              Zambie             Ζάμπια         זמביה
# 2            یمن               Yémen             Υεμένη          תימן
# 3         ویتنام            Viêt Nam            Βιετνάμ       וייטנאם
# 4        ونزوئلا           Venezuela         Βενεζουέλα       ונצואלה
# ..           ...                 ...                ...           ...
# 237    افغانستان         Afghanistan         Αφγανιστάν      אפגניסטן
# 238  یخچال سیاچن  glacier de Siachen  Παγετώνας Σιατσέν  קרחון סיאצ'ן
# 239      جنوبگان         Antarctique         Ανταρκτική    אנטארקטיקה
# 240   سینت مارتن        Saint-Martin     Άγιος Μαρτίνος     סנט מארטן
# 241       تووالو              Tuvalu           Τουβαλού        טובאלו
#
#            NAME_HI           NAME_HU          NAME_ID             NAME_IT  \
# 0      ज़िम्बाब्वे          Zimbabwe         Zimbabwe            Zimbabwe
# 1        ज़ाम्बिया            Zambia           Zambia              Zambia
# 2              यमन             Jemen            Yaman               Yemen
# 3          वियतनाम           Vietnám          Vietnam             Vietnam
# 4       वेनेज़ुएला         Venezuela        Venezuela           Venezuela
# ..             ...               ...              ...                 ...
# 237  अफ़्गानिस्तान       Afganisztán       Afganistan         Afghanistan
# 238        सियाचीन  Siachen-gleccser  Siachen Glacier  ghiacciaio Siachen
# 239    अंटार्कटिका        Antarktika        Antartika           Antartide
# 240   सिंट मार्टेन      Sint Maarten     Sint Maarten        Sint Maarten
# 241         तुवालू            Tuvalu           Tuvalu              Tuvalu
#
#        NAME_JA NAME_KO          NAME_NL           NAME_PL             NAME_PT  \
# 0        ジンバブエ    짐바브웨         Zimbabwe          Zimbabwe            Zimbábue
# 1         ザンビア     잠비아           Zambia            Zambia              Zâmbia
# 2         イエメン      예멘            Jemen             Jemen               Iémen
# 3         ベトナム     베트남          Vietnam           Wietnam            Vietname
# 4        ベネズエラ   베네수엘라        Venezuela         Wenezuela           Venezuela
# ..         ...     ...              ...               ...                 ...
# 237    アフガニスタン  아프가니스탄      Afghanistan        Afganistan         Afeganistão
# 238    シアチェン氷河  시아첸 빙하  Siachengletsjer  Lodowiec Siachen  Glaciar de Siachen
# 239       南極大陸      남극       Antarctica        Antarktyda           Antártida
# 240  シント・マールテン   신트마르턴     Sint Maarten      Sint Maarten        São Martinho
# 241        ツバル     투발루           Tuvalu            Tuvalu              Tuvalu
#
#          NAME_RU            NAME_SV         NAME_TR      NAME_UK  \
# 0       Зимбабве           Zimbabwe        Zimbabve     Зімбабве
# 1         Замбия             Zambia         Zambiya       Замбія
# 2          Йемен              Jemen           Yemen         Ємен
# 3        Вьетнам            Vietnam         Vietnam      В'єтнам
# 4      Венесуэла          Venezuela       Venezuela    Венесуела
# ..           ...                ...             ...          ...
# 237   Афганистан        Afghanistan      Afganistan   Афганістан
# 238       Сиачен  Siachen Glaciären  Siachen Buzulu       Сіачен
# 239   Антарктида          Antarktis      Antarktika   Антарктида
# 240  Синт-Мартен       Sint Maarten    Sint Maarten  Сінт-Мартен
# 241       Тувалу             Tuvalu          Tuvalu       Тувалу
#
#           NAME_UR            NAME_VI NAME_ZH NAME_ZHT          FCLASS_ISO  \
# 0         زمبابوے           Zimbabwe    津巴布韦      辛巴威     Admin-0 country
# 1          زیمبیا             Zambia     赞比亚      尚比亞     Admin-0 country
# 2             یمن              Yemen      也门       葉門     Admin-0 country
# 3          ویتنام           Việt Nam      越南       越南     Admin-0 country
# 4       وینیزویلا          Venezuela    委内瑞拉     委內瑞拉     Admin-0 country
# ..            ...                ...     ...      ...                 ...
# 237     افغانستان        Afghanistan     阿富汗      阿富汗     Admin-0 country
# 238  سیاچن گلیشیر  Sông băng Siachen   锡亚琴冰川    錫亞琴冰川        Unrecognized
# 239     انٹارکٹکا       Châu Nam Cực     南极洲      南極洲  Admin-0 dependency
# 240     سنٹ مارٹن       Sint Maarten   荷属圣马丁    荷屬聖馬丁  Admin-0 dependency
# 241        تووالو             Tuvalu     图瓦卢      吐瓦魯     Admin-0 country
#
#     TLC_DIFF          FCLASS_TLC FCLASS_US FCLASS_FR     FCLASS_RU  \
# 0       None     Admin-0 country      None      None          None
# 1       None     Admin-0 country      None      None          None
# 2       None     Admin-0 country      None      None          None
# 3       None     Admin-0 country      None      None          None
# 4       None     Admin-0 country      None      None          None
# ..       ...                 ...       ...       ...           ...
# 237     None     Admin-0 country      None      None          None
# 238     None        Unrecognized      None      None  Unrecognized
# 239     None  Admin-0 dependency      None      None          None
# 240     None  Admin-0 dependency      None      None          None
# 241     None     Admin-0 country      None      None          None
#
#         FCLASS_ES FCLASS_CN     FCLASS_TW     FCLASS_IN     FCLASS_NP  \
# 0            None      None          None          None          None
# 1            None      None          None          None          None
# 2            None      None          None          None          None
# 3            None      None          None          None          None
# 4            None      None          None          None          None
# ..            ...       ...           ...           ...           ...
# 237          None      None          None          None          None
# 238  Unrecognized      None  Unrecognized  Unrecognized  Unrecognized
# 239          None      None          None          None          None
# 240          None      None          None          None          None
# 241          None      None          None          None          None
#
#         FCLASS_PK     FCLASS_DE     FCLASS_GB     FCLASS_BR     FCLASS_IL  \
# 0            None          None          None          None          None
# 1            None          None          None          None          None
# 2            None          None          None          None          None
# 3            None          None          None          None          None
# 4            None          None          None          None          None
# ..            ...           ...           ...           ...           ...
# 237          None          None          None          None          None
# 238  Unrecognized  Unrecognized  Unrecognized  Unrecognized  Unrecognized
# 239          None          None          None          None          None
# 240          None          None          None          None          None
# 241          None          None          None          None          None
#
#         FCLASS_PS     FCLASS_SA     FCLASS_EG     FCLASS_MA     FCLASS_PT  \
# 0            None          None          None          None          None
# 1            None          None          None          None          None
# 2            None          None          None          None          None
# 3            None          None          None          None          None
# 4            None          None          None          None          None
# ..            ...           ...           ...           ...           ...
# 237          None          None          None          None          None
# 238  Unrecognized  Unrecognized  Unrecognized  Unrecognized  Unrecognized
# 239          None          None          None          None          None
# 240          None          None          None          None          None
# 241          None          None          None          None          None
#
#         FCLASS_AR     FCLASS_JP     FCLASS_KO     FCLASS_VN     FCLASS_TR  \
# 0            None          None          None          None          None
# 1            None          None          None          None          None
# 2            None          None          None          None          None
# 3            None          None          None          None          None
# 4            None          None          None          None          None
# ..            ...           ...           ...           ...           ...
# 237          None          None          None          None          None
# 238  Unrecognized  Unrecognized  Unrecognized  Unrecognized  Unrecognized
# 239          None          None          None          None          None
# 240          None          None          None          None          None
# 241          None          None          None          None          None
#
#         FCLASS_ID     FCLASS_PL     FCLASS_GR     FCLASS_IT     FCLASS_NL  \
# 0            None          None          None          None          None
# 1            None          None          None          None          None
# 2            None          None          None          None          None
# 3            None          None          None          None          None
# 4            None          None          None          None          None
# ..            ...           ...           ...           ...           ...
# 237          None          None          None          None          None
# 238  Unrecognized  Unrecognized  Unrecognized  Unrecognized  Unrecognized
# 239          None          None          None          None          None
# 240          None          None          None          None          None
# 241          None          None          None          None          None
#
#         FCLASS_SE     FCLASS_BD     FCLASS_UA  \
# 0            None          None          None
# 1            None          None          None
# 2            None          None          None
# 3            None          None          None
# 4            None          None          None
# ..            ...           ...           ...
# 237          None          None          None
# 238  Unrecognized  Unrecognized  Unrecognized
# 239          None          None          None
# 240          None          None          None
# 241          None          None          None
#
#                                               geometry
# 0    POLYGON ((31.28789 -22.40205, 31.19727 -22.344...
# 1    POLYGON ((30.39609 -15.64307, 30.25068 -15.643...
# 2    MULTIPOLYGON (((53.08564 16.64839, 52.58145 16...
# 3    MULTIPOLYGON (((104.06396 10.39082, 104.08301 ...
# 4    MULTIPOLYGON (((-60.82119 9.13838, -60.94141 9...
# ..                                                 ...
# 237  POLYGON ((66.52227 37.34849, 66.82773 37.37129...
# 238  POLYGON ((77.04863 35.10991, 77.00449 35.19634...
# 239  MULTIPOLYGON (((-45.71777 -60.52090, -45.49971...
# 240  POLYGON ((-63.12305 18.06895, -63.01118 18.068...
# 241  POLYGON ((179.21367 -8.52422, 179.20059 -8.534...
#
# [242 rows x 169 columns]

# %%
# quick view
countries.plot()
# Out:
# <AxesSubplot:>

# %%
# re-assign the column names - .str.lower() makes them lower case
countries.columns = countries.columns.str.lower()
print(countries.columns, '\n')
# Out:
# Index(['featurecla', 'scalerank', 'labelrank', 'sovereignt', 'sov_a3',
#        'adm0_dif', 'level', 'type', 'tlc', 'admin',
#        ...
#        'fclass_tr', 'fclass_id', 'fclass_pl', 'fclass_gr', 'fclass_it',
#        'fclass_nl', 'fclass_se', 'fclass_bd', 'fclass_ua', 'geometry'],
#       dtype='object', length=169)

# %%
# check if there is a name that doesn't appear in the dataset
for name in scandi_names:
    if name  not in countries.values:
        print(name)
# Out:
# Aland Islands

# %%
scandi_countries = countries.loc[countries.admin.isin(scandi_names),['admin','type','geometry']]
scandi_countries
# Out:
#              admin               type  \
# 48          Sweden  Sovereign country
# 88          Norway  Sovereign country
# 145        Iceland  Sovereign country
# 169        Finland            Country
# 182  Faroe Islands         Dependency
# 183        Denmark            Country
#
#                                               geometry
# 48   MULTIPOLYGON (((19.07646 57.83594, 18.99375 57...
# 88   MULTIPOLYGON (((20.62217 69.03687, 20.49199 69...
# 145  POLYGON ((-15.54312 66.22852, -15.42847 66.224...
# 169  MULTIPOLYGON (((24.15547 65.80527, 24.04902 65...
# 182  MULTIPOLYGON (((-6.62319 61.80596, -6.64277 61...
# 183  MULTIPOLYGON (((12.56875 55.78506, 12.57119 55...

# %%
# check Aland Islands is nowehere in data frame
'Aland Islands' in countries.values
# Out:
# False

# %%
n_comms.head()
# Out:
#   country  n_communities
# 0      AX              1
# 1      BY              8
# 2      CA              7
# 3      DK             72
# 4      EE             14

# %%
scandi_countries = pd.merge(scandi_countries,scandi_n_comms)
scandi_countries
# Out:
#            admin               type  \
# 0         Sweden  Sovereign country
# 1         Norway  Sovereign country
# 2        Iceland  Sovereign country
# 3        Finland            Country
# 4  Faroe Islands         Dependency
# 5        Denmark            Country
#
#                                             geometry country  n_communities
# 0  MULTIPOLYGON (((19.07646 57.83594, 18.99375 57...      SE            133
# 1  MULTIPOLYGON (((20.62217 69.03687, 20.49199 69...      NO             48
# 2  POLYGON ((-15.54312 66.22852, -15.42847 66.224...      IS              5
# 3  MULTIPOLYGON (((24.15547 65.80527, 24.04902 65...      FI             98
# 4  MULTIPOLYGON (((-6.62319 61.80596, -6.64277 61...      FO              1
# 5  MULTIPOLYGON (((12.56875 55.78506, 12.57119 55...      DK             72

# %%
scandi_communities = communities[communities.country.isin(scandi_codes)]
scandi_communities
# Out:
#                 name  population country  geoname-id  \
# 612             Umeå       74005      SE      602150
# 613       Skellefteå       30839      SE      602913
# 614            Piteå       22044      SE      603570
# 615            Luleå       45551      SE      604490
# 616           Kiruna       18154      SE      605155
# ...              ...         ...     ...         ...
# 1372         Majorna       29254      SE     6619708
# 1379       Ytrebygda       24044      NO     6697344
# 1382          Onsala       13370      SE     6943587
# 1402  Länsi-Turunmaa       15498      FI     7911309
# 1403            Alby       11400      SE     7931985
#
#                        geometry
# 612   POINT (20.25972 63.82842)
# 613   POINT (20.95279 64.75067)
# 614   POINT (21.47944 65.31717)
# 615   POINT (22.15465 65.58415)
# 616   POINT (20.22513 67.85572)
# ...                         ...
# 1372  POINT (11.91605 57.69195)
# 1379   POINT (5.28236 60.30504)
# 1382  POINT (12.02903 57.42531)
# 1402  POINT (22.30040 60.29972)
# 1403  POINT (17.85380 59.23350)
#
# [358 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
scandi_countries.plot(ax=ax,
                      column='n_communities',
                       cmap='BuPu',
                       legend=True,
                       edgecolor="0.8",
                       legend_kwds={"shrink":.6}
                       )
                       
scandi_communities.plot(ax=ax, 
                        alpha=0.3,
                        edgecolor='blue')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
scandi_countries.plot(ax=ax,
                      column='n_communities',
                      cmap='BuPu',
                      edgecolor="black",
                      legend=True,
                      legend_kwds={"shrink":.6}
                       )
                       
ctx.add_basemap(ax=ax, 
               attribution=False,
               crs=scandi_countries.crs.to_string())
               #source=cx.providers.Stamen.TonerLite)

ax.set_title('Number of ')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

plt.show()
